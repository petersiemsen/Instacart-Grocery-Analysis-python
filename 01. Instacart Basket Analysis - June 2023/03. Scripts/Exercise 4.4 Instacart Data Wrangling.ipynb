# %% [markdown]
# # Data Wrangling from the lesson

# %%
# Import Libraries, Step 3

import pandas as pd
import numpy as np
import os

# %%
# Setting up the default path

path = r'C:\Users\peter\Desktop\Career Foundry - Data Analyst\Data Immersion\Achievement 4 - Python\01. Instacart Basket Analysis - June 2023'

# %%
# Importing the orders and product csv files

df_orders = pd.read_csv(os.path.join(path, '02. Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_products = pd.read_csv(os.path.join(path, '02. Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Dropping the eval_set column

df_orders.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# Getting the value count of the variables in a specified column

df_orders['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
# Renaming the column 'order_dow' to 'orders_day_of_week'

df_orders.rename(columns = {'orders_day_of_week' : 'order_day_of_week'}, inplace = True)

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Changing the data type of 'order_id' to a string value so that df.describe() does not include it
# in it's calculations

df_orders['order_id'] = df_orders['order_id'].astype('str')

# %%
df_orders['order_id'].dtype
# Out:
# dtype('O')

# %%
# Importing the department csv file for analysis

df_dep = pd.read_csv(os.path.join(path, '02. Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep_t = df_dep.T

# %%
# Resetting the index on our new table so that we have the appropriate numbering on
# the left side as a column

df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Creating a new header

new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Making a new df that takes the data from row 1 onward. This will be our new table 
# where we will add our new_header to

df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# creating a data dictionary using the departments.csv for all the 
# department ID #'s

data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# creating a subset of data where we specifically look at any rows
# that have a department ID of 19, aka snacks 

df_snacks = df_products[df_products['department_id']==19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# # Data Wrangling for 4.4 Task

# %%
# Question 2: find another variable in the df_orders datafram that doesn't 
# need to be included in your analysis as a numeric variable and change it to 
# a suitable format

# I have decided to change the user_id variable to a string so that it isn't 
# calculated in the descriptive statistics

df_orders['user_id'] = df_orders['user_id'].astype('str')

# %%
df_orders.head()
# Out:
#   order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329       1    prior             1          2                  8
# 1  2398795       1    prior             2          3                  7
# 2   473747       1    prior             3          3                 12
# 3  2254736       1    prior             4          4                  7
# 4   431534       1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders['user_id'].dtype
# Out:
# dtype('O')

# %%
# Question 3: Look for a variable in your df_ords dataframe with an unintuitive 
# name and change its name without overwriting the data frame.

# I'll be changing the column 'order_hour_of_day'. I honestly don't think any of 
# the remaining columns are that unintuitive, but for the sake of the exercise, 
# I chose this one. I also used inplace = False as to not overwrite the column name. 

df_orders.rename(columns = {'order_hour_of_day' : 'order_time'}, inplace = False)
# Out:
#         order_id user_id eval_set  order_number  order_dow  order_time  \
# 0        2539329       1    prior             1          2           8
# 1        2398795       1    prior             2          3           7
# 2         473747       1    prior             3          3          12
# 3        2254736       1    prior             4          4           7
# 4         431534       1    prior             5          4          15
# ...          ...     ...      ...           ...        ...         ...
# 3421078  2266710  206209    prior            10          5          18
# 3421079  1854736  206209    prior            11          4          10
# 3421080   626363  206209    prior            12          1          12
# 3421081  2977660  206209    prior            13          1          12
# 3421082   272231  206209    train            14          6          14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# Question 4: Your client wants to know what the busiest hour is for placing orders. 
# Find the frequency of the corresponding variable and share your findings.

# The busiest hour for ordering is at 10am. It has a count of 288,418 occurences. 

df_orders['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
# Question 5: Determine the meaning behind a value of 4 in the "department_id" column 
# within the df_prods dataframe using a data dictionary.

# The department_id for 4 is 'produce'.

print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# Question 6: The sales team in your client’s organization wants to know more about breakfast item sales. 
# Create a subset containing only the required information.

df_breakfast = df_products.loc[df_products['department_id']==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# Question 7: Find product details about all items in the following categories:
# alcohol, deli, beverages, meat/seafood. 

df_dinner_parties = df_products.loc[df_products['department_id'].isin([5,20,7,12])]

# %%
# observing 20 rows of the new subsetted datafram

df_dinner_parties.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %%
# Question 8: How many rows does the last dataframe you created have? 

df_dinner_parties.shape

# the df_dinner_parties dataframe has 7650 rows.
# Out:
# (7650, 5)

# %%
# Question 9: Someone from the data engineers team in Instacart thinks they’ve spotted 
# something strange about the customer with a "user_id" of “1.” 
# Extract all the information you can about this user.

# subsetting the data
df_user_id_1 = df_orders[df_orders['user_id']=='1']

# %%
# info on the new user_id_1 dataframe
df_user_id_1
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2398795       1    prior             2          3                  7
# 2    473747       1    prior             3          3                 12
# 3   2254736       1    prior             4          4                  7
# 4    431534       1    prior             5          4                 15
# 5   3367565       1    prior             6          2                  7
# 6    550135       1    prior             7          1                  9
# 7   3108588       1    prior             8          1                 14
# 8   2295261       1    prior             9          1                 16
# 9   2550362       1    prior            10          4                  8
# 10  1187899       1    train            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
# Question 10: You also need to provide some details about this user’s behavior. 
# What basic stats can you provide based on the information you have?

# basic descriptive statistics
df_user_id_1.describe()
# Out:
#        order_number  order_dow  order_hour_of_day  days_since_prior_order
# count     11.000000  11.000000          11.000000               10.000000
# mean       6.000000   2.636364          10.090909               19.000000
# std        3.316625   1.286291           3.477198                9.030811
# min        1.000000   1.000000           7.000000                0.000000
# 25%        3.500000   1.500000           7.500000               14.250000
# 50%        6.000000   3.000000           8.000000               19.500000
# 75%        8.500000   4.000000          13.000000               26.250000
# max       11.000000   4.000000          16.000000               30.000000

# %%
# Question 12: Export the df_orders dataframe. 

df_orders.to_csv(os.path.join(path,'02. Data','Prepared Data','orders_wrangled.csv'))

# %%
# Question 13: Export the df_dep_t_new dataframe. 

df_dep_t_new.to_csv(os.path.join(path, '02. Data', 'Prepared Data', 'departments_wrangled.csv'))
